# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.6/873.6 kB 50.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://v8docs.ultralytics.com/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %%
# %cd {HOME}
# !yolo task=detect mode=predict conf=0.25 save=True model={HOME}/weights/yolov10s.pt source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 15.9M/15.9M [00:00<00:00, 258MB/s]
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10s summary (fused): 293 layers, 8,096,880 parameters, 0 gradients, 24.8 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 52.9MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 2 dogs, 1 backpack, 107.5ms
# Speed: 9.9ms preprocess, 107.5ms inference, 90.5ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'	 images		     waterbottleconveyorbelt.zip
#  data.zip		 images.zip	     xml_result
#  dist			'My Drive'	     yolov10-driving-rules-main.zip
#  dlss_snowymoon.io.zip	 saved_model	     yolov10-object-tracking-counting-main.zip
#  freedomtech.zip	 testgooglemachine   yolov4-tiny
#  image_dataset		 vehiclecount

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/freedomtech.zip
# Out:
# /content/datasets
# Archive:  /content/gdrive/MyDrive/freedomtech.zip
#    creating: freedomtech/
#    creating: freedomtech/images/
#    creating: freedomtech/images/training/
#   inflating: freedomtech/images/training/classes.txt
#   inflating: freedomtech/images/training/img_0.jpg
#   inflating: freedomtech/images/training/img_0.txt
#   inflating: freedomtech/images/training/img_1.jpg
#   inflating: freedomtech/images/training/img_1.txt
#   inflating: freedomtech/images/training/img_10.jpg
#   inflating: freedomtech/images/training/img_10.txt
#   inflating: freedomtech/images/training/img_11.jpg
#   inflating: freedomtech/images/training/img_11.txt
#   inflating: freedomtech/images/training/img_12.jpg
#   inflating: freedomtech/images/training/img_12.txt
#   inflating: freedomtech/images/training/img_13.jpg
#   inflating: freedomtech/images/training/img_13.txt
#   inflating: freedomtech/images/training/img_14.jpg
#   inflating: freedomtech/images/training/img_14.txt
# ...

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov10s.pt data=/content/datasets/freedomtech/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# /content
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
